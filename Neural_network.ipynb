# %% [markdown]
# <a href="https://colab.research.google.com/github/pr0-dm/AI/blob/main/Neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import lib & modules
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
# %matplotlib inline
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import utils

# %%
#del your datasets on the 2parts learning & tests
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
#preload data
plt.figure()
plt.imshow(x_train[12])
plt.colorbar()
plt.grid(False)

# %%
#normalase the data
x_train = x_train/255
x_test = x_test/255

#preload data
plt.figure()
plt.imshow(x_train[12])
plt.colorbar()
plt.grid(False)

# %%
#show the net-pictures
plt.figure(figsize = (10,10))
for i in range (25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_train[i]) #black&white pic-->use code plt.imshow(x_train[i],cmap = plt.cm.binary) 
  plt.xlabel(class_names[y_train[i]])

# %%
#set the model of AI
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax"),
])

# %%
#compilate the model
model.compile(optimizer=tf.keras.optimizers.SGD(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#print the param
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
#start learning AI
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3535 - accuracy: 0.8771
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3487 - accuracy: 0.8786
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3431 - accuracy: 0.8800
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3378 - accuracy: 0.8817
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3333 - accuracy: 0.8839
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3288 - accuracy: 0.8850
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3253 - accuracy: 0.8851
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3212 - accuracy: 0.8870
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3175 - accuracy: 0.8889
# Epoch 10/10
# ...

# %%
#verify with target
test_loss, test_acc = model.evaluate(x_test, y_test) 
print('Test Accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3755 - accuracy: 0.8680
# Test Accuracy: 0.8679999709129333

# %%
#vangas move
predictions = model.predict(x_train)
predictions[0]
# Out:
# array([5.1842575e-09, 4.7546184e-10, 5.0974497e-10, 2.4619679e-10,
#        1.2294223e-11, 1.3477575e-04, 7.0153567e-09, 5.5488403e-04,
#        1.1864350e-06, 9.9930918e-01], dtype=float32)

# %%
np.argmax(predictions[12])
# Out:
# 5

# %%
y_train[12]
# Out:
# 5

# %%
plt.figure()
plt.imshow(x_train[12])
plt.colorbar
plt.grid(False)

# %%
  class_names[np.argmax(predictions[12])]
# Out:
# 'Sandal'
